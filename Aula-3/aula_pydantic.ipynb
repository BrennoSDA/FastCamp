# %%
#definicao do pydantic e suas dependencias
[tool.poetry]
name = "Pydantic refresh"
version = "0.0.1"
description = ""
authors = ["Arjan"]

[tool.poetry.dependencies]
python = "^3.11"
pydantic_config = {"extras": ["email"], "version": "^2.6.1"}
fastapi = "^0.109.2"
httpx = "^0.26.0"

[build-system]
requires = ["poetry-core"]
build-backend = "poetry.core.mansonry.api"
